# %%
import pandas as pd

# %%
using_collab = True

if using_collab :
  from google.colab import drive
  drive.mount('/content/drive')

file_path = "/content/drive/MyDrive" #file_path를 설정해주세요.
# Out:
# Mounted at /content/drive

# %%
rawdata= pd.read_csv(file_path+'/KISTI/rawdata/조달청 분류 체계 전체자료.csv') #

# %%
rawdata.head(5)
# Out:
#             DB_regTime           DB_modTime  thngClsfcNo   thngClsfcNoNm  \
# 0  2021-09-29 19:10:40  2021-09-29 19:10:40           10    산동식물및동식물성생산품
# 1  2021-09-29 19:10:40  2021-09-29 19:10:40           11  광물,직물및비식용동식물자원
# 2  2021-09-29 19:10:40  2021-09-29 19:10:40           12            화학제품
# 3  2021-09-29 19:10:40  2021-09-29 19:10:40           13     수지,고무,탄성중합체
# 4  2021-09-29 19:10:40  2021-09-29 19:10:40           14       종이원료및종이제품
#
#   thngClsfcNoEngNm                               prdctClsfcRltnDscrpt  \
# 0              NaN  생명이 있는 야생과 재배성의 식물과 동물, 생명이 있는 식물들과 그들의 씨앗, 생명...
# 1              NaN  암석, 토양, 광석, 정제 금속 또는 귀금속, 비식용 식물, 삼림, 동물제품, 천연...
# 2              NaN  각종 산업분야에서 사용되는 생산 원료, 부원료 또는 완제품으로서의 고체, 액체, 기...
# 3              NaN  천연에서 생산되거나 합성 가공된 수지, 로진, 고무 및 엘라스토머, 발포, 필름 등...
# 4              NaN  상업적 프린터, 용지, 봉투, 복사, 메모, 그리고 특별한 요구사항에 의해 만들어진...
#
#    prdctClsfcNoAplYn  prdctClsfcNoUseYn  prdctClsfcNoDltYn
# ...

# %%
rawdata8 = rawdata[rawdata['thngClsfcNo'].between(10000000,99999999)]
rawdata8.head()
# Out:
#                DB_regTime           DB_modTime  thngClsfcNo thngClsfcNoNm  \
# 2664  2021-09-22 11:08:47  2021-09-29 20:29:38     10101502             개
# 2665  2021-09-22 11:08:47  2021-09-29 20:29:38     10101504            밍크
# 2666  2021-09-22 11:08:47  2021-09-29 20:29:38     10101506             말
# 2667  2021-10-13 19:42:48  2021-10-14 17:35:43     10101507          양(羊)
# 2668  2021-10-13 19:42:48  2021-10-14 17:35:43     10101510             쥐
#
#      thngClsfcNoEngNm                               prdctClsfcRltnDscrpt  \
# 2664             Dogs  한자로 견, 구, 술 등으로 표기하며 포유류 중 가장 오래된 가축으로 거의 전세계에...
# 2665             Mink  털가죽 짐승으로 유명한 밍크는 북아메리카, 유럽과 아시아의 전북구에 서식 모습은 족...
# 2666           Horses       기제목 말과의 포유류로 중요한 가축의 하나이며, 전세계에서 널리 사육되고 있음.
# 2667            Sheep  양은 가축인 면양, 무플런양, 아르갈리양, 빅혼, 우리알, 아시아무플런, 달리빅혼,...
# 2668             Mice         포유류 쥐목 쥐아목의 총칭. 남극과 뉴질랜드 이외의 세계 각 지방에 분포함.
#
#       prdctClsfcNoAplYn  prdctClsfcNoUseYn  prdctClsfcNoDltYn
# ...

# %%
len(rawdata8)
# Out:
# 10941

# %%
rawdata6 = rawdata[rawdata['thngClsfcNo'].between(100000,999999)] #unspsc class 에 해당
rawdata6.head()
# Out:
#               DB_regTime           DB_modTime  thngClsfcNo thngClsfcNoNm  \
# 480  2021-09-22 11:08:47  2021-09-22 11:08:47       101015           가축류
# 481  2021-09-22 11:08:47  2021-09-22 11:08:47       101016        조류및가금류
# 482  2021-09-22 11:08:47  2021-09-22 11:08:47       101019           곤충류
# 483  2021-09-22 11:08:47  2021-09-22 11:08:47       101020          야생동물
# 484  2021-09-22 11:08:47  2021-09-22 11:08:47       101113   애완동물액세서리및장비
#
#     thngClsfcNoEngNm                               prdctClsfcRltnDscrpt  \
# 480              NaN      인류가 야생동물을 순치·개량한 것으로 사람의 보호 밑에서 자유로이 번식하는 동물.
# 481              NaN  척추동물의 한 강으로 앞다리는 날개로 변형되어 비상생활에 적응되었고, 입은 부리로 ...
# 482              NaN                       동물분류상 절지동물 곤충강에 속하는 소동물의 총칭.
# 483              NaN                               산과 들에 저절로 나서 자라는 동물.
# 484              NaN          애완동물을 돌보고 꾸미거나 훈련하기 위해 사용하는 각종 액세서리 및 장비.
#
#      prdctClsfcNoAplYn  prdctClsfcNoUseYn  prdctClsfcNoDltYn
# ...

# %%
len(rawdata6)
# Out:
# 2184

# %%
rawdata4 = rawdata[rawdata['thngClsfcNo'].between(1000,9999)] #unspsc class 에 해당
rawdata4.head()
# Out:
#              DB_regTime           DB_modTime  thngClsfcNo thngClsfcNoNm  \
# 56  2021-09-22 11:07:24  2021-09-22 11:07:24         1010           산동물
# 57  2021-09-22 11:07:24  2021-09-22 11:07:24         1011        애완동물용품
# 58  2021-09-22 11:07:24  2021-09-22 11:07:24         1012          동물사료
# 59  2021-09-22 11:07:24  2021-09-22 11:07:24         1013     동물수용소및보관소
# 60  2021-09-22 11:07:24  2021-09-22 11:07:24         1014      마구류및마차용품
#
#    thngClsfcNoEngNm                               prdctClsfcRltnDscrpt  \
# 56              NaN                               생명이 있는 야생 및 사육하는 동물.
# 57              NaN                           애완동물을 양육하는데 필요한 용품 및 용구.
# 58              NaN  동물의 건강을 유지하고 그 동물이 가지고 있는 생산능력을 충분히 발휘시키기 위한 목...
# 59              NaN       생명이 있는 야생 및 사육하는 동물의 보호, 수용, 사육에 필요한 재료와 설비.
# 60              NaN         말 및 마차에 장치하는 장구의 총칭으로 승마용 ·마차용 ·경작용 등이 있음.
#
#     prdctClsfcNoAplYn  prdctClsfcNoUseYn  prdctClsfcNoDltYn
# ...

# %%
len(rawdata4)
# Out:
# 424

# %%
rawdata2 = rawdata[rawdata['thngClsfcNo'].between(10,99)] #unspsc class 에 해당
rawdata2.head()
# Out:
#             DB_regTime           DB_modTime  thngClsfcNo   thngClsfcNoNm  \
# 0  2021-09-29 19:10:40  2021-09-29 19:10:40           10    산동식물및동식물성생산품
# 1  2021-09-29 19:10:40  2021-09-29 19:10:40           11  광물,직물및비식용동식물자원
# 2  2021-09-29 19:10:40  2021-09-29 19:10:40           12            화학제품
# 3  2021-09-29 19:10:40  2021-09-29 19:10:40           13     수지,고무,탄성중합체
# 4  2021-09-29 19:10:40  2021-09-29 19:10:40           14       종이원료및종이제품
#
#   thngClsfcNoEngNm                               prdctClsfcRltnDscrpt  \
# 0              NaN  생명이 있는 야생과 재배성의 식물과 동물, 생명이 있는 식물들과 그들의 씨앗, 생명...
# 1              NaN  암석, 토양, 광석, 정제 금속 또는 귀금속, 비식용 식물, 삼림, 동물제품, 천연...
# 2              NaN  각종 산업분야에서 사용되는 생산 원료, 부원료 또는 완제품으로서의 고체, 액체, 기...
# 3              NaN  천연에서 생산되거나 합성 가공된 수지, 로진, 고무 및 엘라스토머, 발포, 필름 등...
# 4              NaN  상업적 프린터, 용지, 봉투, 복사, 메모, 그리고 특별한 요구사항에 의해 만들어진...
#
#    prdctClsfcNoAplYn  prdctClsfcNoUseYn  prdctClsfcNoDltYn
# ...

# %%
unsp = pd.read_excel(file_path+'/KISTI/rawdata/UNv240301.xlsx',skiprows=12)

# %%
unsp.head(5)
# Out:
#      Version     Key   Segment  \
# 0  UNv240301  100001  10000000
# 1  UNv240301  100002  10000000
# 2  UNv240301  100003  10000000
# 3  UNv240301  100004  10000000
# 4  UNv240301  100005  10000000
#
#                                        Segment Title  \
# 0  Live Plant and Animal Material and Accessories...
# 1  Live Plant and Animal Material and Accessories...
# 2  Live Plant and Animal Material and Accessories...
# 3  Live Plant and Animal Material and Accessories...
# 4  Live Plant and Animal Material and Accessories...
#
#                                   Segment Definition      Family  \
# 0  This segment includes live, wild and domestica...         NaN
# 1  This segment includes live, wild and domestica...  10100000.0
# 2  This segment includes live, wild and domestica...  10100000.0
# 3  This segment includes live, wild and domestica...  10100000.0
# 4  This segment includes live, wild and domestica...  10100000.0
#
# ...

# %%
len(unsp)
# Out:
# 157168

# %%
unsp2 = unsp[['Segment', 'Segment Title', 'Segment Definition']]

# %%
unsp2.head()
# Out:
#     Segment                                      Segment Title  \
# 0  10000000  Live Plant and Animal Material and Accessories...
# 1  10000000  Live Plant and Animal Material and Accessories...
# 2  10000000  Live Plant and Animal Material and Accessories...
# 3  10000000  Live Plant and Animal Material and Accessories...
# 4  10000000  Live Plant and Animal Material and Accessories...
#
#                                   Segment Definition
# 0  This segment includes live, wild and domestica...
# 1  This segment includes live, wild and domestica...
# 2  This segment includes live, wild and domestica...
# 3  This segment includes live, wild and domestica...
# 4  This segment includes live, wild and domestica...

# %%
unsp4 = unsp[['Family', 'Family Title', 'Family Definition']]

# %%
unsp4.head()
# Out:
#        Family  Family Title Family Definition
# 0         NaN           NaN               NaN
# 1  10100000.0  Live animals               NaN
# 2  10100000.0  Live animals               NaN
# 3  10100000.0  Live animals               NaN
# 4  10100000.0  Live animals               NaN

# %%
unsp6 = unsp[['Class', 'Class Title', 'Class Definition']]

# %%
unsp6.head()
# Out:
#         Class Class Title Class Definition
# 0         NaN         NaN              NaN
# 1         NaN         NaN              NaN
# 2  10101500.0   Livestock              NaN
# 3  10101500.0   Livestock              NaN
# 4  10101500.0   Livestock              NaN

# %%
unsp8 = unsp[['Commodity', 'Commodity Title', 'Commodity Definition']]

# %%
unsp8.head()
# Out:
#     Commodity Commodity Title Commodity Definition
# 0         NaN             NaN                  NaN
# 1         NaN             NaN                  NaN
# 2         NaN             NaN                  NaN
# 3  10101501.0            Cats                  NaN
# 4  10101502.0            Dogs                  NaN

# %%
unsp8 = unsp8.dropna(subset=['Commodity'])  # 8자리 분류체계 명 NaN 값을 제거
print(len(unsp8))
unsp8 = unsp8.dropna(subset=['Commodity Definition']) # 8자리 분류체계 부연설명 NaN값 제거
print(len(unsp8))
unsp8['Commodity'] = unsp8['Commodity'].astype(int)  # 데이터 타입 변경
# Out:
# 148613
# 135593

# %%
merged8 = pd.merge(rawdata8, unsp8, left_on='thngClsfcNo', right_on='Commodity')

# %%
len(merged8)
# Out:
# 2744

# %%
merged8.head()
# Out:
#             DB_regTime           DB_modTime  thngClsfcNo thngClsfcNoNm  \
# 0  2021-10-13 19:42:48  2021-10-14 17:35:43     10101516           가축소
# 1  2021-10-13 19:42:48  2021-10-14 17:35:43     10141505         안장용패드
# 2  2021-10-13 19:42:48  2021-10-14 17:35:43     10152004         활엽수묘목
# 3  2021-10-13 19:42:48  2021-10-14 17:35:43     10152005         침엽수묘목
# 4  2021-10-13 19:42:49  2021-10-14 17:35:43     10161513          야자나무
#
#             thngClsfcNoEngNm  \
# 0                     Cattle
# 1                Saddle pads
# 2  Latifoliate tree seedings
# 3      Conifer tree seedings
# 4                 Palm trees
#
#                                 prdctClsfcRltnDscrpt  prdctClsfcNoAplYn  \
# 0       소목 소과의 포유류로 분류는 소목 소과이고 생활방식은 초식성 반추동물 주행성임.                  1
# 1                            말을 탈 때 안장 밑에 까는 모포를 말함.                  1
# 2       잎이 넓은 나무를 통틀어 이르는 활엽수의 묘포(苗圃,모밭)에서 기른 어린 나무.                  1
# ...

# %%
unsp6 = unsp6.dropna(subset=['Class', 'Class Title', 'Class Definition'])  # 8자리 분류체계 명 NaN 값을 제거
print(len(unsp6))
unsp6 = unsp6.drop_duplicates(subset=['Class'])
print(len(unsp6))
unsp6['Class'] = unsp6['Class'].astype(int)  # 데이터 타입 변경
unsp6['Class'] = unsp6['Class'].astype(str).str[:-2].str.zfill(6).astype(int)
# Out:
# 6362
# 6362

# %%
unsp6.head()
# Out:
#       Class                                  Class Title  \
# 105  101021                 Birds and fowl hatching eggs
# 389  101523                   Legume seeds and seedlings
# 393  101524                    Tuber seeds and seedlings
# 632  101718                            Soil conditioners
# 666  102015  Live blue or lavender or purple rose bushes
#
#                                       Class Definition
# 105                  Fertilized bird eggs for grow-out
# 389  Seeds of plants in the family Fabaceae (or Leg...
# 393  Seeds or seedlings of plants that have a thick...
# 632  Products that are used to improve the physical...
# 666  Live bushes including the roots of blue or lav...

# %%
merged6 = pd.merge(rawdata6, unsp6, left_on='thngClsfcNo', right_on='Class')

# %%
len(merged6)
# Out:
# 424

# %%
merged6.head()
# Out:
#             DB_regTime           DB_modTime  thngClsfcNo thngClsfcNoNm  \
# 0  2021-09-22 11:17:50  2021-09-22 11:17:50       111220        성형목재제품
# 1  2021-09-22 11:17:50  2021-09-22 11:17:50       111624             솜
# 2  2021-09-22 11:17:50  2021-09-22 11:17:50       111815       비철금속산화물
# 3  2021-09-22 11:17:50  2021-09-22 11:17:50       111916           금속설
# 4  2021-10-13 19:42:50  2021-10-13 19:42:50       121647           감수제
#
#   thngClsfcNoEngNm                               prdctClsfcRltnDscrpt  \
# 0              NaN  목재부스러기(대패밥·톱밥)나 목재 조각을 접착제로 결합시켜 천연목재와 비슷한 외관이...
# 1              NaN                            목화씨에 달라붙은 털과 같은 섬유의 뭉치.
# 2              NaN               철산화물을 제외한 모든 금속산화물로, 광석형태로 된 것도 포함함.
# 3              NaN             사람의 생활이나 사업활동에 필요 없게 된 금속물질의 부스러기나 파쇠.
# 4              NaN  액체 속에 미세하게 밀집된 고체 분말을 집어 넣으면 고체 입자는 서로 집합하여 집합...
#
#    prdctClsfcNoAplYn  prdctClsfcNoUseYn  prdctClsfcNoDltYn   Class  \
# ...

# %%
unsp4 = unsp4.dropna(subset=['Family', 'Family Title', 'Family Definition'])  # 8자리 분류체계 명 NaN 값을 제거
print(len(unsp4))
unsp4 = unsp4.drop_duplicates(subset=['Family'])
print(len(unsp4))
unsp4['Family'] = unsp4['Family'].astype(int)  # 데이터 타입 변경
unsp4['Family'] = unsp4['Family'].astype(str).str[:-4].str.zfill(4).astype(int)
# Out:
# 262
# 1

# %%
merged4 = pd.merge(rawdata4, unsp4, left_on='thngClsfcNo', right_on='Family')

# %%
len(merged4)
# Out:
# 0

# %%
merged4.head()
# Out:
# Empty DataFrame
# Columns: [DB_regTime, DB_modTime, thngClsfcNo, thngClsfcNoNm, thngClsfcNoEngNm, prdctClsfcRltnDscrpt, prdctClsfcNoAplYn, prdctClsfcNoUseYn, prdctClsfcNoDltYn, Family, Family Title, Family Definition]
# Index: []

# %%
unsp2 = unsp2.dropna(subset=['Segment', 'Segment Title', 'Segment Definition'])  # 8자리 분류체계 명 NaN 값을 제거
print(len(unsp2))
unsp2 = unsp2.drop_duplicates(subset=['Segment'])
print(len(unsp2))
unsp2['Segment'] = unsp2['Segment'].astype(int)  # 데이터 타입 변경
unsp2['Segment'] = unsp2['Segment'].astype(str).str[:-6].str.zfill(6).astype(int)
# Out:
# 157168
# 58

# %%
merged2 = pd.merge(rawdata2, unsp2, left_on='thngClsfcNo', right_on='Segment')

# %%
len(merged2)
# Out:
# 55

# %%
merged2.head()
# Out:
#             DB_regTime           DB_modTime  thngClsfcNo   thngClsfcNoNm  \
# 0  2021-09-29 19:10:40  2021-09-29 19:10:40           10    산동식물및동식물성생산품
# 1  2021-09-29 19:10:40  2021-09-29 19:10:40           11  광물,직물및비식용동식물자원
# 2  2021-09-29 19:10:40  2021-09-29 19:10:40           12            화학제품
# 3  2021-09-29 19:10:40  2021-09-29 19:10:40           13     수지,고무,탄성중합체
# 4  2021-09-29 19:10:40  2021-09-29 19:10:40           14       종이원료및종이제품
#
#   thngClsfcNoEngNm                               prdctClsfcRltnDscrpt  \
# 0              NaN  생명이 있는 야생과 재배성의 식물과 동물, 생명이 있는 식물들과 그들의 씨앗, 생명...
# 1              NaN  암석, 토양, 광석, 정제 금속 또는 귀금속, 비식용 식물, 삼림, 동물제품, 천연...
# 2              NaN  각종 산업분야에서 사용되는 생산 원료, 부원료 또는 완제품으로서의 고체, 액체, 기...
# 3              NaN  천연에서 생산되거나 합성 가공된 수지, 로진, 고무 및 엘라스토머, 발포, 필름 등...
# 4              NaN  상업적 프린터, 용지, 봉투, 복사, 메모, 그리고 특별한 요구사항에 의해 만들어진...
#
#    prdctClsfcNoAplYn  prdctClsfcNoUseYn  prdctClsfcNoDltYn  Segment  \
# ...

# %%
print(len(merged8))
print(len(rawdata8))
print(len(merged6))
print(len(rawdata6))
print(len(merged4))
print(len(rawdata4))
print(len(merged2))
print(len(rawdata2))
print(len(rawdata2+rawdata4+rawdata6+rawdata8))
print(len(merged2+merged4+merged6+merged8))
# Out:
# 2744
# 10941
# 424
# 2184
# 0
# 424
# 55
# 56
# 13605
# 2744

# %%
print(len(rawdata))
print(len(merged2+merged4+merged6+merged8))
# Out:
# 35440
# 2744

# %% [markdown]
# ## Task 1 -1 : 분류체계 설명 -> 분류체계 예측

# %% [markdown]
# ### 예시
# **instruction**
# 다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
#
# **input**
# 생명이 있는 야생과 재배성의 식물과 동물, 생명이 있는 식물들과 그들의 씨앗, 생명이 있는 식물과 동물의 보호, 수용, 사육에 필요한 재료와 설비
#
# **output**
# 산동식물및동식물성생산품

# %%
#instruction #context #response #category

task1_1_data = pd.DataFrame()

# Generate 'context' column
task1_1_data['context'] = rawdata['prdctClsfcRltnDscrpt']


# Generate 'response' column
task1_1_data['response'] =rawdata['thngClsfcNoNm']
task1_1_data['instruction'] = "다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오."
task1_1_data['category'] = "task1-1"

# Generate '원본데이터' column
#task1_1_data['원본데이터']=rawdata.index[task1_1_data['context'] == rawdata['prdctClsfcRltnDscrpt']]

task1_1_data['index'] = task1_1_data.index


task1_1_data = task1_1_data[['instruction','context','response','category','index']]

task1_1_data.head()
# Out:
#                                 instruction  \
# 0  다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
# 1  다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
# 2  다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
# 3  다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
# 4  다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
#
#                                              context        response category  \
# 0  생명이 있는 야생과 재배성의 식물과 동물, 생명이 있는 식물들과 그들의 씨앗, 생명...    산동식물및동식물성생산품  task1-1
# 1  암석, 토양, 광석, 정제 금속 또는 귀금속, 비식용 식물, 삼림, 동물제품, 천연...  광물,직물및비식용동식물자원  task1-1
# 2  각종 산업분야에서 사용되는 생산 원료, 부원료 또는 완제품으로서의 고체, 액체, 기...            화학제품  task1-1
# 3  천연에서 생산되거나 합성 가공된 수지, 로진, 고무 및 엘라스토머, 발포, 필름 등...     수지,고무,탄성중합체  task1-1
# 4  상업적 프린터, 용지, 봉투, 복사, 메모, 그리고 특별한 요구사항에 의해 만들어진...       종이원료및종이제품  task1-1
#
#    index
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4

# %%
len(task1_1_data)
# Out:
# 35440

# %% [markdown]
# ## Task 1-2 : 분류체계 -> 분류체계 설명

# %% [markdown]
# ### 예시
# **instruction**
# 다음은 분류 체계입니다. 해당 분류체계에 대해 상세하게 설명하시오.
#
# **input**
# 산동식물및동식물성생산품
#
# **output**
# 생명이 있는 야생과 재배성의 식물과 동물, 생명이 있는 식물들과 그들의 씨앗, 생명이 있는 식물과 동물의 보호, 수용, 사육에 필요한 재료와 설비

# %%
task1_2_data = pd.DataFrame()

# Generate 'context' column
task1_2_data['context'] = rawdata['thngClsfcNoNm']

# Generate 'response' column
task1_2_data['response'] = rawdata['prdctClsfcRltnDscrpt']

#context와 response의 내용이 동일한 부분을 제거한다면,
#task1_2_data = task1_2[task1_2_data['context']!=task1_2_data['response']]

task1_2_data['instruction'] = "다음은 분류 체계입니다. 해당 분류체계에 대해 상세하게 설명하시오."
task1_2_data['category'] = "task1-2"

task1_2_data['index'] = task1_2_data.index


task1_2_data = task1_2_data[['instruction','context','response','category','index']]

task1_2_data.head()
# Out:
#                              instruction         context  \
# 0  다음은 분류 체계입니다. 해당 분류체계에 대해 상세하게 설명하시오.    산동식물및동식물성생산품
# 1  다음은 분류 체계입니다. 해당 분류체계에 대해 상세하게 설명하시오.  광물,직물및비식용동식물자원
# 2  다음은 분류 체계입니다. 해당 분류체계에 대해 상세하게 설명하시오.            화학제품
# 3  다음은 분류 체계입니다. 해당 분류체계에 대해 상세하게 설명하시오.     수지,고무,탄성중합체
# 4  다음은 분류 체계입니다. 해당 분류체계에 대해 상세하게 설명하시오.       종이원료및종이제품
#
#                                             response category  index
# 0  생명이 있는 야생과 재배성의 식물과 동물, 생명이 있는 식물들과 그들의 씨앗, 생명...  task1-2      0
# 1  암석, 토양, 광석, 정제 금속 또는 귀금속, 비식용 식물, 삼림, 동물제품, 천연...  task1-2      1
# 2  각종 산업분야에서 사용되는 생산 원료, 부원료 또는 완제품으로서의 고체, 액체, 기...  task1-2      2
# 3  천연에서 생산되거나 합성 가공된 수지, 로진, 고무 및 엘라스토머, 발포, 필름 등...  task1-2      3
# 4  상업적 프린터, 용지, 봉투, 복사, 메모, 그리고 특별한 요구사항에 의해 만들어진...  task1-2      4

# %%
len(task1_2_data)
# Out:
# 35440

# %% [markdown]
# ## Task 2 : 이어질 카테고리 설명 예측

# %% [markdown]
# ### 예시
# **instruction**
# 다음은 분류체계와 분류체계에 대한 상세 설명 일부입니다. 이어지는 설명을 쓰세요.
#
# **input**
# 산동식물및동식물성생산품 ; 생명이 있는 야생과 재배성의 식물과 동물, 생명이 있는 식물들과 그들의
#
# **output**
# 씨앗, 생명이 있는 식물과 동물의 보호, 수용, 사육에 필요한 재료와 설비

# %%
#설명을 단어 기준으로 쪼개서 절반을 Input, 절반을 output
def split_words(sentence):
  return sentence.split( )

def group_words(words):
  half_length = len(words) // 2
  first_half_words = words[:half_length]
  second_half_words = words[half_length:]
  first_half_words = ' '.join(first_half_words)
  second_half_words = ' '.join(second_half_words)
  return first_half_words, second_half_words

def get_first_half_words(sentence):
  return group_words(split_words(sentence))[0]

def get_second_half_words(sentence):
  return group_words(split_words(sentence))[1]

rawdata['first_half_words'] = rawdata['prdctClsfcRltnDscrpt'].apply(get_first_half_words)
rawdata['second_half_words'] = rawdata['prdctClsfcRltnDscrpt'].apply(get_second_half_words)

rawdata.head()
# Out:
#             DB_regTime           DB_modTime  thngClsfcNo   thngClsfcNoNm  \
# 0  2021-09-29 19:10:40  2021-09-29 19:10:40           10    산동식물및동식물성생산품
# 1  2021-09-29 19:10:40  2021-09-29 19:10:40           11  광물,직물및비식용동식물자원
# 2  2021-09-29 19:10:40  2021-09-29 19:10:40           12            화학제품
# 3  2021-09-29 19:10:40  2021-09-29 19:10:40           13     수지,고무,탄성중합체
# 4  2021-09-29 19:10:40  2021-09-29 19:10:40           14       종이원료및종이제품
#
#   thngClsfcNoEngNm                               prdctClsfcRltnDscrpt  \
# 0              NaN  생명이 있는 야생과 재배성의 식물과 동물, 생명이 있는 식물들과 그들의 씨앗, 생명...
# 1              NaN  암석, 토양, 광석, 정제 금속 또는 귀금속, 비식용 식물, 삼림, 동물제품, 천연...
# 2              NaN  각종 산업분야에서 사용되는 생산 원료, 부원료 또는 완제품으로서의 고체, 액체, 기...
# 3              NaN  천연에서 생산되거나 합성 가공된 수지, 로진, 고무 및 엘라스토머, 발포, 필름 등...
# 4              NaN  상업적 프린터, 용지, 봉투, 복사, 메모, 그리고 특별한 요구사항에 의해 만들어진...
#
#    prdctClsfcNoAplYn  prdctClsfcNoUseYn  prdctClsfcNoDltYn  \
# ...

# %%
len(rawdata)
# Out:
# 35440

# %%
task2_data = pd.DataFrame()
# Generate 'context' column
task2_data['context'] = "분류체계: " + rawdata['thngClsfcNoNm']\
                        + " 상세설명 : " + rawdata['first_half_words']

# Generate 'response' column
task2_data['response'] = rawdata['second_half_words']


task2_data['instruction'] = "다음은 분류체계와 분류체계에 대한 상세 설명 일부입니다. 이어지는 설명을 쓰세요."
task2_data['category'] = "task2"

task2_data['index'] = task2_data.index

task2_data = task2_data[['instruction','context','response','category','index']]

task2_data.tail()
# Out:
#                                          instruction  \
# 35435  다음은 분류체계와 분류체계에 대한 상세 설명 일부입니다. 이어지는 설명을 쓰세요.
# 35436  다음은 분류체계와 분류체계에 대한 상세 설명 일부입니다. 이어지는 설명을 쓰세요.
# 35437  다음은 분류체계와 분류체계에 대한 상세 설명 일부입니다. 이어지는 설명을 쓰세요.
# 35438  다음은 분류체계와 분류체계에 대한 상세 설명 일부입니다. 이어지는 설명을 쓰세요.
# 35439  다음은 분류체계와 분류체계에 대한 상세 설명 일부입니다. 이어지는 설명을 쓰세요.
#
#                                                  context  \
# 35435    분류체계: 발광형경계석 상세설명 : 발광형 광원이 삽입된 블록으로, 차도와 인도 또는
# 35436         분류체계: 난방온수조절시스템 상세설명 : 실내 온도나 난방수 온도를 감지하여
# 35437  분류체계: 블록일체형매립레일 상세설명 : 철도용 레일을 지면에 매립하기 위해, 설치 전에
# 35438  분류체계: AED통합관리시스템 상세설명 : AED(자동심장충격기)의 실시간 정상작동 유무
# 35439  분류체계: 의약품주입량감시조절기및수액세트 상세설명 : 환자에게 중력을 이용하여 주입...
#
#                                                 response category  index
# 35435               차도와 차도의 경계부에 설치하는 경계석으로서 반사판형식은 제외함.    task2  35435
# 35436                          설정된 온도에 따라 난방수를 제어하는 시스템.    task2  35436
# 35437                   일정 규격의 완성된 블록의 형태로 일체화하여 제작된 레일.    task2  35437
# ...

# %%
len(task2_data)
# Out:
# 35440

# %% [markdown]
# ## Task 3 : 상,하위 카테고리 예측
#
# > 들여쓴 블록

# %% [markdown]
# ### 예시
# 물품목록번호는 2자리씩 4단계 계층구조로 이루어진 8자리 숫자이다.
#
# **instruction**
# 다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
#
# **input**
# 물품분류번호는 5126 입니다. 분류체계는 신경계감각기관용의약품 입니다.
#
# **output**
# 대분류: 의약품

# %%
#ㅇㅇ : lv1(대분류)  , ㅇㅇ : lv2(중분류) ,ㅇㅇ : lv3(소분류), ㅇㅇ-ㅇㅇ : 품명 - 세부번호
#계층 데이터프레임 만들기
lv_data = pd.DataFrame()

lv_data['thngClsfcNoNm']=rawdata['thngClsfcNoNm']
lv_data['thngClsfcNo']=rawdata['thngClsfcNo']
lv_data['대분류_No'] = rawdata['thngClsfcNo'].astype(str).str[:2]
lv_data['중분류_No'] = rawdata['thngClsfcNo'].astype(str).str[:4]
lv_data['소분류_No'] = rawdata['thngClsfcNo'].astype(str).str[:6]
lv_data['품명_No'] = rawdata['thngClsfcNo'].astype(str).str[:8]
lv_data['세부번호_No'] = rawdata['thngClsfcNo'].astype(str).str[:10]


lv_data['대분류_NoNm'] = lv_data['대분류_No'].map(lv_data.groupby('대분류_No')['thngClsfcNoNm'].first())
lv_data['중분류_NoNm'] = lv_data['중분류_No'].map(lv_data.groupby('중분류_No')['thngClsfcNoNm'].first())
lv_data['소분류_NoNm'] = lv_data['소분류_No'].map(lv_data.groupby('소분류_No')['thngClsfcNoNm'].first())
lv_data['품명_NoNm'] = lv_data['품명_No'].map(lv_data.groupby('품명_No')['thngClsfcNoNm'].first())

lv_data['index'] = lv_data.index

lv_data = lv_data[['thngClsfcNo','thngClsfcNoNm','대분류_No','중분류_No','소분류_No','품명_No','세부번호_No',
                   '대분류_NoNm','중분류_NoNm','소분류_NoNm','품명_NoNm', 'index']]

lv_data.head(100)
# Out:
#     thngClsfcNo   thngClsfcNoNm 대분류_No 중분류_No 소분류_No 품명_No 세부번호_No  \
# 0            10    산동식물및동식물성생산품     10     10     10    10      10
# 1            11  광물,직물및비식용동식물자원     11     11     11    11      11
# 2            12            화학제품     12     12     12    12      12
# 3            13     수지,고무,탄성중합체     13     13     13    13      13
# 4            14       종이원료및종이제품     14     14     14    14      14
# ..          ...             ...    ...    ...    ...   ...     ...
# 95         2111        낚시및양식용장비     21   2111   2111  2111    2111
# 96         2210        건설기계및중장비     22   2210   2210  2210    2210
# 97         2310          원료가공기계     23   2310   2310  2310    2310
# 98         2312    섬유및직물기계및액세서리     23   2312   2312  2312    2312
# 99         2313       연마가공기기및장비     23   2313   2313  2313    2313
#
#           대분류_NoNm        중분류_NoNm        소분류_NoNm         품명_NoNm  index
# 0     산동식물및동식물성생산품    산동식물및동식물성생산품    산동식물및동식물성생산품    산동식물및동식물성생산품      0
# ...

# %%
#lv_data.groupby(['대분류_No','중분류_No','소분류_No','품명_No','대분류_NoNm','중분류_NoNm','소분류_NoNm','품명_NoNm']).size().reset_index().to_csv("/content/drive/MyDrive/KISTI/zodal1234.csv")

# %%
len(lv_data)
# Out:
# 35440

# %%
#데이터갯수
#`thngClsfcNo` (물품분류번호)
'''
4자리일때 → 대분류예측
6자리일때 → 대분류,중분류예측
8자리일때 → 대분류,중분류,소분류 예측
10자리일때→ 대분류,중분류,소분류,품명 예측
데이터 개수 : 35384개'''
a0 = lv_data['thngClsfcNo'].astype(str).str.len() == 2

#4자리 물품분류번호 -> 대분류 예측
a1= lv_data['thngClsfcNo'].astype(str).str.len() == 4
#print(rawdata['thngClsfcNo'][a1].astype(str))
count1 = sum(a1)
print(count1)

#6자리 물품분류번호 -> 대분류,중분류 예측
a2 = lv_data['thngClsfcNo'].astype(str).str.len() == 6
count2 = sum(a2)
#print(rawdata['thngClsfcNo'][a2])
print(count2)

#8자리 물품분류번호 -> 대분류,중분류,소분류 예측
a3 = lv_data['thngClsfcNo'].astype(str).str.len() == 8
count3 = sum(a3)
print(count3)

#10자리 물품분류번호 -> 대분류,중분류,소분류,품명 예측
a4 = lv_data['thngClsfcNo'].astype(str).str.len() == 10
count4 = sum(a4)
print(count4)

print(count1+count2+count3+count4)
# Out:
# 424
# 2184
# 10941
# 21835
# 35384

# %%
digit4 = lv_data[lv_data['thngClsfcNo'].between(1000,9999)]
digit4.head()
# Out:
#     thngClsfcNo thngClsfcNoNm 대분류_No 중분류_No 소분류_No 품명_No 세부번호_No  \
# 56         1010           산동물     10   1010   1010  1010    1010
# 57         1011        애완동물용품     10   1011   1011  1011    1011
# 58         1012          동물사료     10   1012   1012  1012    1012
# 59         1013     동물수용소및보관소     10   1013   1013  1013    1013
# 60         1014      마구류및마차용품     10   1014   1014  1014    1014
#
#         대분류_NoNm   중분류_NoNm   소분류_NoNm    품명_NoNm  index
# 56  산동식물및동식물성생산품        산동물        산동물        산동물     56
# 57  산동식물및동식물성생산품     애완동물용품     애완동물용품     애완동물용품     57
# 58  산동식물및동식물성생산품       동물사료       동물사료       동물사료     58
# 59  산동식물및동식물성생산품  동물수용소및보관소  동물수용소및보관소  동물수용소및보관소     59
# 60  산동식물및동식물성생산품   마구류및마차용품   마구류및마차용품   마구류및마차용품     60

# %%
task3_1_data = pd.DataFrame()

# Generate 'context' column : lv 2 주어졌을 때 lv 1 예측 (4자리)
task3_1_data['context'] = "물품분류번호는" + digit4["thngClsfcNo"].astype(str) \
                          + "이고, 분류체계는 " + digit4["thngClsfcNoNm"]+ "입니다"



# Generate 'response' column
task3_1_data['response'] = "대분류: " + digit4["대분류_NoNm"]

task3_1_data['instruction'] = "다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오."
task3_1_data['category'] = "task3-1"

task3_1_data['index'] = digit4['index']

task3_1_data = task3_1_data[['instruction','context','response','category','index']]

task3_1_data.head()
# Out:
#                                          instruction  \
# 56  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 57  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 58  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 59  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 60  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
#
#                               context           response category  index
# 56        물품분류번호는1010이고, 분류체계는 산동물입니다  대분류: 산동식물및동식물성생산품  task3-1     56
# 57     물품분류번호는1011이고, 분류체계는 애완동물용품입니다  대분류: 산동식물및동식물성생산품  task3-1     57
# 58       물품분류번호는1012이고, 분류체계는 동물사료입니다  대분류: 산동식물및동식물성생산품  task3-1     58
# 59  물품분류번호는1013이고, 분류체계는 동물수용소및보관소입니다  대분류: 산동식물및동식물성생산품  task3-1     59
# 60   물품분류번호는1014이고, 분류체계는 마구류및마차용품입니다  대분류: 산동식물및동식물성생산품  task3-1     60

# %%
len(task3_1_data)
# Out:
# 424

# %%
digit6 = lv_data[lv_data['thngClsfcNo'].between(100000,999999)]
digit6.head()
# Out:
#      thngClsfcNo thngClsfcNoNm 대분류_No 중분류_No  소분류_No   품명_No 세부번호_No  \
# 480       101015           가축류     10   1010  101015  101015  101015
# 481       101016        조류및가금류     10   1010  101016  101016  101016
# 482       101019           곤충류     10   1010  101019  101019  101019
# 483       101020          야생동물     10   1010  101020  101020  101020
# 484       101113   애완동물액세서리및장비     10   1011  101113  101113  101113
#
#          대분류_NoNm 중분류_NoNm     소분류_NoNm      품명_NoNm  index
# 480  산동식물및동식물성생산품      산동물          가축류          가축류    480
# 481  산동식물및동식물성생산품      산동물       조류및가금류       조류및가금류    481
# 482  산동식물및동식물성생산품      산동물          곤충류          곤충류    482
# 483  산동식물및동식물성생산품      산동물         야생동물         야생동물    483
# 484  산동식물및동식물성생산품   애완동물용품  애완동물액세서리및장비  애완동물액세서리및장비    484

# %%
task3_2_data = pd.DataFrame()

# Generate 'context' column : lv 2 주어졌을 때 lv 1 예측 (4자리)
task3_2_data['context'] = "물품분류번호는" + digit6["thngClsfcNo"].astype(str) \
                          + "이고, 분류체계는 " + digit6["thngClsfcNoNm"]+ "입니다"



# Generate 'response' column
task3_2_data['response'] = "대분류: " + digit6["대분류_NoNm"] + " 중분류: " + digit6["중분류_NoNm"]

task3_2_data['instruction'] = "다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오."
task3_2_data['category'] = "task3-2"

task3_2_data['index'] = digit6['index']

task3_2_data = task3_2_data[['instruction','context','response','category','index']]

task3_2_data.head()
# Out:
#                                           instruction  \
# 480  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 481  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 482  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 483  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 484  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
#
#                                    context                       response  \
# 480          물품분류번호는101015이고, 분류체계는 가축류입니다     대분류: 산동식물및동식물성생산품 중분류: 산동물
# 481       물품분류번호는101016이고, 분류체계는 조류및가금류입니다     대분류: 산동식물및동식물성생산품 중분류: 산동물
# 482          물품분류번호는101019이고, 분류체계는 곤충류입니다     대분류: 산동식물및동식물성생산품 중분류: 산동물
# 483         물품분류번호는101020이고, 분류체계는 야생동물입니다     대분류: 산동식물및동식물성생산품 중분류: 산동물
# 484  물품분류번호는101113이고, 분류체계는 애완동물액세서리및장비입니다  대분류: 산동식물및동식물성생산품 중분류: 애완동물용품
#
#     category  index
# 480  task3-2    480
# 481  task3-2    481
# 482  task3-2    482
# 483  task3-2    483
# 484  task3-2    484

# %%
len(task3_2_data)
# Out:
# 2184

# %%
digit8 = lv_data[lv_data['thngClsfcNo'].between(10000000,99999999)]
digit8.head()
# Out:
#       thngClsfcNo thngClsfcNoNm 대분류_No 중분류_No  소분류_No     품명_No   세부번호_No  \
# 2664     10101502             개     10   1010  101015  10101502  10101502
# 2665     10101504            밍크     10   1010  101015  10101504  10101504
# 2666     10101506             말     10   1010  101015  10101506  10101506
# 2667     10101507          양(羊)     10   1010  101015  10101507  10101507
# 2668     10101510             쥐     10   1010  101015  10101510  10101510
#
#           대분류_NoNm 중분류_NoNm 소분류_NoNm 품명_NoNm  index
# 2664  산동식물및동식물성생산품      산동물      가축류       개   2664
# 2665  산동식물및동식물성생산품      산동물      가축류      밍크   2665
# 2666  산동식물및동식물성생산품      산동물      가축류       말   2666
# 2667  산동식물및동식물성생산품      산동물      가축류    양(羊)   2667
# 2668  산동식물및동식물성생산품      산동물      가축류       쥐   2668

# %%
task3_3_data = pd.DataFrame()

# Generate 'context' column : lv 2 주어졌을 때 lv 1 예측 (4자리)
task3_3_data['context'] = "물품분류번호는" + digit8["thngClsfcNo"].astype(str) \
                          + " 이고, 분류체계는 " + digit8["thngClsfcNoNm"]+ "입니다"



# Generate 'response' column
task3_3_data['response'] = "대분류: " + digit8["대분류_NoNm"] + " 중분류: " + digit8["중분류_NoNm"] \
                           + " 소분류: " + digit8["소분류_NoNm"]

task3_3_data['instruction'] = "다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오."
task3_3_data['category'] = "task3-3"

task3_3_data['index'] = digit8['index']

task3_3_data = task3_3_data[['instruction','context','response','category', 'index']]

task3_3_data.head()
# Out:
#                                            instruction  \
# 2664  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 2665  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 2666  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 2667  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 2668  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
#
#                                 context                             response  \
# 2664     물품분류번호는10101502 이고, 분류체계는 개입니다  대분류: 산동식물및동식물성생산품 중분류: 산동물 소분류: 가축류
# 2665    물품분류번호는10101504 이고, 분류체계는 밍크입니다  대분류: 산동식물및동식물성생산품 중분류: 산동물 소분류: 가축류
# 2666     물품분류번호는10101506 이고, 분류체계는 말입니다  대분류: 산동식물및동식물성생산품 중분류: 산동물 소분류: 가축류
# 2667  물품분류번호는10101507 이고, 분류체계는 양(羊)입니다  대분류: 산동식물및동식물성생산품 중분류: 산동물 소분류: 가축류
# 2668     물품분류번호는10101510 이고, 분류체계는 쥐입니다  대분류: 산동식물및동식물성생산품 중분류: 산동물 소분류: 가축류
#
#      category  index
# 2664  task3-3   2664
# 2665  task3-3   2665
# 2666  task3-3   2666
# 2667  task3-3   2667
# 2668  task3-3   2668

# %%
len(task3_3_data)
# Out:
# 10941

# %%
digit10 = lv_data[lv_data['thngClsfcNo'].between(1000000000,9999999999)]
digit10.head()
# Out:
#        thngClsfcNo thngClsfcNoNm 대분류_No 중분류_No  소분류_No     품명_No     세부번호_No  \
# 13605   1010150201             개     10   1010  101015  10101502  1010150201
# 13606   1010150401            밍크     10   1010  101015  10101504  1010150401
# 13607   1010150601             말     10   1010  101015  10101506  1010150601
# 13608   1010150701             양     10   1010  101015  10101507  1010150701
# 13609   1010151001             쥐     10   1010  101015  10101510  1010151001
#
#            대분류_NoNm 중분류_NoNm 소분류_NoNm 품명_NoNm  index
# 13605  산동식물및동식물성생산품      산동물      가축류       개  13605
# 13606  산동식물및동식물성생산품      산동물      가축류      밍크  13606
# 13607  산동식물및동식물성생산품      산동물      가축류       말  13607
# 13608  산동식물및동식물성생산품      산동물      가축류    양(羊)  13608
# 13609  산동식물및동식물성생산품      산동물      가축류       쥐  13609

# %%
task3_4_data = pd.DataFrame()

# Generate 'context' column : lv 2 주어졌을 때 lv 1 예측 (4자리)
task3_4_data['context'] = "물품분류번호는" + digit10["thngClsfcNo"].astype(str) \
                          + " 이고, 분류체계는 " + digit10["thngClsfcNoNm"]+ "입니다"



# Generate 'response' column
task3_4_data['response'] = "대분류: " + digit10["대분류_NoNm"] + " 중분류: " + digit10["중분류_NoNm"] \
                           + " 소분류: " + digit10["소분류_NoNm"] + " 품명: " + digit10["품명_NoNm"]

task3_4_data['instruction'] = "다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오."
task3_4_data['category'] = "task3-4"

task3_4_data['index'] = digit10['index']

task3_4_data = task3_4_data[['instruction','context','response','category', 'index']]

task3_4_data.head()
# Out:
#                                             instruction  \
# 13605  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 13606  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 13607  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 13608  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 13609  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
#
#                                  context  \
# 13605   물품분류번호는1010150201 이고, 분류체계는 개입니다
# 13606  물품분류번호는1010150401 이고, 분류체계는 밍크입니다
# 13607   물품분류번호는1010150601 이고, 분류체계는 말입니다
# 13608   물품분류번호는1010150701 이고, 분류체계는 양입니다
# 13609   물품분류번호는1010151001 이고, 분류체계는 쥐입니다
#
#                                            response category  index
# 13605     대분류: 산동식물및동식물성생산품 중분류: 산동물 소분류: 가축류 품명: 개  task3-4  13605
# 13606    대분류: 산동식물및동식물성생산품 중분류: 산동물 소분류: 가축류 품명: 밍크  task3-4  13606
# 13607     대분류: 산동식물및동식물성생산품 중분류: 산동물 소분류: 가축류 품명: 말  task3-4  13607
# 13608  대분류: 산동식물및동식물성생산품 중분류: 산동물 소분류: 가축류 품명: 양(羊)  task3-4  13608
# ...

# %%
task3_4_data[8500:9000]
# Out:
#                                             instruction  \
# 22105  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 22106  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 22107  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 22108  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 22109  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# ...                                                 ...
# 22600  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 22601  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 22602  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 22603  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 22604  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
#
#                                          context  \
# 22105    물품분류번호는4229501103 이고, 분류체계는 의료용카메라헤드입니다
# 22106     물품분류번호는4229501501 이고, 분류체계는 내시경용현미경입니다
# 22107   물품분류번호는4229509901 이고, 분류체계는 체외형의료용카메라입니다
# 22108      물품분류번호는4229510101 이고, 분류체계는 소독대야걸이입니다
# ...

# %%
len(task3_4_data)
# Out:
# 21835

# %%
appended_table = pd.concat([task1_1_data, task1_2_data,task2_data,
                            task3_1_data, task3_2_data, task3_3_data, task3_4_data], ignore_index=True)

appended_table['data'] = '조달청'

# %%
appended_table
# Out:
#                                              instruction  \
# 0               다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
# 1               다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
# 2               다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
# 3               다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
# 4               다음은 분류 체계에 대한 상세설명입니다. 해당하는 분류체계를 예측하시오.
# ...                                                  ...
# 141699  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 141700  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 141701  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 141702  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
# 141703  다음은 물품분류번호와 해당하는 분류체계입니다.이 분류체계의 상위 분류체계를 예측하시오.
#
#                                                   context  \
# 0       생명이 있는 야생과 재배성의 식물과 동물, 생명이 있는 식물들과 그들의 씨앗, 생명...
# 1       암석, 토양, 광석, 정제 금속 또는 귀금속, 비식용 식물, 삼림, 동물제품, 천연...
# 2       각종 산업분야에서 사용되는 생산 원료, 부원료 또는 완제품으로서의 고체, 액체, 기...
# ...

# %%
appended_table.to_csv(file_path+"/KISTI/dataset/조달청_task.csv")
